# %%
import utils

# %%
from utils import (
    compute_per_doc_cp_shard_doc_len,
    generate_doc_lens,
    generate_doc_lens_1LNS,
    compute_workload,
)

# %%
K = 1024
doc_lens_even = [2 * K] * 16
doc_lens_1LNS = [16 * K] + [1 * K] * 16

# %%
# Out:
# Packed Batch 1:
#   Micro-batch 1: IDs=[2, 3], Lengths=[8, 3], Total=11
#   Micro-batch 2: IDs=[4, 1], Lengths=[7, 5], Total=12
#
# Packed Batch 2:
#   Micro-batch 1: IDs=[7, 8], Lengths=[9, 2], Total=11
#   Micro-batch 2: IDs=[5, 6], Lengths=[6, 4], Total=10
