# %%
import pandas as pd

# %%
dfw2 = pd.read_json('allreduce.w2.jsonl', lines=True)
dfw4 = pd.read_json('allreduce.w4.jsonl', lines=True)

# %%
ax = dfw2.plot(x='tensor_size', y='mean_time_ms', kind='line', logx=True, logy=True, marker='o', label='world_size 2')
dfw4.plot(x='tensor_size', y='mean_time_ms', kind='line', logx=True, logy=True, marker='o', ax=ax, label='world_size 4')
# Out:
# <Axes: xlabel='tensor_size'>

# %%
# df = dfw4
df = dfw2
df['throughput'] = df['data_size_mb'] / df['mean_time_ms']
df
# Out:
#     tensor_size  data_size_mb  world_size  iterations  mean_time_ms  \
# 0             2          0.00           2          10         0.026
# 1             4          0.00           2          10         0.010
# 2             8          0.00           2          10         0.040
# 3            16          0.00           2          10         0.010
# 4            32          0.00           2          10         0.011
# 5            64          0.00           2          10         0.011
# 6           128          0.00           2          10         0.011
# 7           256          0.00           2          10         0.011
# 8           512          0.00           2          10         0.011
# 9          1024          0.00           2          10         0.011
# 10         2048          0.01           2          10         0.012
# 11         4096          0.02           2          10         0.013
# 12         8192          0.03           2          10         0.013
# 13        16384          0.06           2          10         0.013
# 14        32768          0.12           2          10         0.014
# 15        65536          0.25           2          10         0.018
# 16       131072          0.50           2          10         0.048
# 17       262144          1.00           2          10         0.077
# 18       524288          2.00           2          10         0.351
# 19      1048576          4.00           2          10         0.238
# 20      2097152          8.00           2          10         0.184
# 21      4194304         16.00           2          10         0.312
# 22      8388608         32.00           2          10         0.558
# 23     16777216         64.00           2          10         1.052
# 24     33554432        128.00           2          10         2.007
# 25     67108864        256.00           2          10         4.028
# 26    134217728        512.00           2          10         7.723
# 27    268435456       1024.00           2          10        15.027
# 28    536870912       2048.00           2           5        29.059
# 29   1073741824       4096.00           2           5        57.381
# 30   2147483648       8192.00           2           5       114.962
# 31   4294967296      16384.00           2           5       230.036
# 32   8589934592      32768.00           2           5       460.089
# 33  17179869184      65536.00           2           5       918.523
#
#     std_time_ms  min_time_ms  max_time_ms  throughput
# 0         0.047        0.010        0.168    0.000000
# 1         0.000        0.010        0.011    0.000000
# 2         0.089        0.010        0.307    0.000000
# 3         0.000        0.010        0.011    0.000000
# 4         0.000        0.010        0.011    0.000000
# 5         0.000        0.010        0.011    0.000000
# 6         0.000        0.010        0.011    0.000000
# 7         0.000        0.011        0.011    0.000000
# 8         0.000        0.011        0.011    0.000000
# 9         0.000        0.011        0.011    0.000000
# 10        0.000        0.012        0.012    0.833333
# 11        0.000        0.013        0.013    1.538462
# 12        0.000        0.013        0.013    2.307692
# 13        0.000        0.013        0.013    4.615385
# 14        0.000        0.014        0.015    8.571429
# 15        0.000        0.018        0.019   13.888889
# 16        0.065        0.026        0.242   10.416667
# 17        0.092        0.046        0.354   12.987013
# 18        0.743        0.061        2.553    5.698006
# 19        0.357        0.089        1.275   16.806723
# 20        0.086        0.149        0.440   43.478261
# 21        0.088        0.281        0.576   51.282051
# 22        0.089        0.526        0.825   57.347670
# 23        0.089        1.017        1.320   60.836502
# 24        0.085        1.959        2.257   63.776781
# 25        0.191        3.835        4.416   63.555114
# 26        0.451        7.367        8.753   66.295481
# 27        0.826       14.476       17.439   68.144007
# 28        0.414       28.720       29.857   70.477305
# 29        0.646       56.848       58.623   71.382513
# 30        0.908      114.246      116.717   71.258329
# 31        1.085      228.183      231.560   71.223635
# 32        1.162      458.461      461.975   71.221003
# 33        2.475      915.109      921.276   71.349329
